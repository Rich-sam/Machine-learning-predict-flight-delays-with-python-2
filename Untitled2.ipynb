# %% [markdown]
# <a href="https://colab.research.google.com/github/Rich-sam/Machine-learning-predict-flight-delays-with-python-2/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
#Define and compile the neural network
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# Provide the data

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %% [markdown]
# Train the neural network

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 115.9154
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 91.2133
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 71.7786
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 56.4879
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 44.4577
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 34.9925
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 27.5455
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 21.6862
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 17.0761
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 13.4488
# Epoch 11/500
# 1/1 [==============================] - 0s 3ms/step - loss: 10.5947
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 8.3489
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[30.99516]]
